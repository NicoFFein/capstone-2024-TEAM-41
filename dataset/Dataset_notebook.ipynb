# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage.feature import local_binary_pattern, hog
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.preprocessing.image import img_to_array, load_img


from tensorflow.keras.preprocessing import image
import numpy as np
import tensorflow as tf
import keras
import pandas as pd
import cv2
from PIL import Image
from tqdm import tqdm

from skimage.io import imread
from skimage.transform import rescale
from skimage.feature import hog
from skimage import exposure
from skimage import color

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from keras.models import Sequential, Model, load_model
from tensorflow.keras import callbacks
from tensorflow.keras.optimizers import Adam, Adamax
from keras.layers import Input, UpSampling2D, Conv2D, concatenate, MaxPooling2D, Flatten, Dense, Dropout, Activation, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.utils import load_img, img_to_array
from keras.regularizers import l1, l2

from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input # Changed import path

import os
from math import ceil
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
import os
import pandas as pd

import shutil


original_csv_path = 'metadata_standardized.csv'

original_df = pd.read_csv(original_csv_path)

# %%
df = original_df[['names', 'types']]

df = df[df['types'] != -1]


df['types'].value_counts()
# Out:
# 0    7549
# 1    4767
# Name: types, dtype: int64

# %%
df.head()
# Out:
#                      names  types
# 0  OIA-ODIR-TEST-OFFLINE-1      0
# 1  OIA-ODIR-TEST-OFFLINE-2      0
# 2  OIA-ODIR-TEST-OFFLINE-4      0
# 3  OIA-ODIR-TEST-OFFLINE-5      0
# 4  OIA-ODIR-TEST-OFFLINE-6      0

# %%
import matplotlib.pyplot as plt

# Group by 'label' and count the occurrences, then plot as a horizontal bar chart
df.groupby('types').size().plot(kind='barh', color=sns.color_palette('Dark2'))

# Customize the plot to match the style
plt.xlabel('Count')
plt.ylabel('Label')
plt.title('Label Distribution')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# %%
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# Define the destination folder and function as before
destination_folder = '/Users/nemekhbayarnomin/Documents/Graduation_project/Report1/Datasets/SMDG_dataset/full-fundus'

# Modify the function to display images as needed
def display_images(df, rows, cols, dest):
    fig, axes = plt.subplots(rows, cols, figsize=(8, 8))
    for r in range(rows):
        for c in range(cols):
            index = r * cols + c
            if index < len(df):
                img_path = df.iloc[index]['names'] + '.png'
                image_path = os.path.join(dest, img_path)
                label = df.iloc[index]['types']
                img = Image.open(image_path)
                axes[r, c].imshow(img)
                axes[r, c].set_title(f'Label: {label}')
                axes[r, c].axis('off')
            else:
                axes[r, c].axis('off')
    plt.tight_layout()
    plt.show()

# Select 2 images per label (0 and 1)
sampled_df = df.groupby('types').apply(lambda x: x.sample(n=2)).reset_index(drop=True)

# Display the selected images
rows, cols = 2, 2  # Since we are displaying 4 images (2 per label)
display_images(sampled_df, rows, cols, destination_folder)

# %%
import os
from PIL import Image
from collections import Counter

# Define the path to the dataset folder
destination_folder = '/Users/nemekhbayarnomin/Documents/Graduation_project/Report1/Datasets/SMDG_dataset/full-fundus'

# Initialize a Counter to store image sizes
image_sizes = Counter()

# Iterate through each image in the dataset folder
for image_name in os.listdir(destination_folder):
    # Ensure the file is an image (e.g., png, jpg, etc.)
    if image_name.lower().endswith(('.png', '.jpg', '.jpeg')):
        # Get the full path of the image
        image_path = os.path.join(destination_folder, image_name)
        # Open the image and get its size
        with Image.open(image_path) as img:
            size = img.size  # (width, height)
            image_sizes[size] += 1

# Display the different image sizes and their counts
print("Image sizes and their counts:")
for size, count in image_sizes.items():
    print(f"Size {size}: {count} images")
# Out:
# Image sizes and their counts:
# Size (512, 512): 12449 images

# %%
#extracting refuge dataset with refuge_df, refuge_train, refuge_val


refuge_df = df[df['names'].str.contains("REFUGE")]
refuge_df['types'].value_counts()
# Out:
# 0    720
# 1     80
# Name: types, dtype: int64

# %%
#extracting origa dataset with origa_df


origa_df = df[df['names'].str.contains("ORIGA")]
origa_df['types'].value_counts()
# Out:
# 0    482
# 1    168
# Name: types, dtype: int64

# %%
g1020_df = df[df['names'].str.contains("G1020")]
g1020_df['types'].value_counts()
# Out:
# 0    724
# 1    296
# Name: types, dtype: int64

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

# Plot label distribution for each DataFrame
for ax, dataset_df, title in zip(axes, [refuge_df, origa_df, g1020_df], ["REFUGE", "ORIGA", "G1020"]):
    dataset_df.groupby('types').size().plot(kind='barh', ax=ax, color=sns.color_palette('Dark2'))
    ax.set_title(f'Label Distribution in {title}')
    ax.set_xlabel('Count')
    ax.spines[['top', 'right']].set_visible(False)

# Set a common y-label for all plots
axes[0].set_ylabel('Label')

# Display the figure
plt.tight_layout()
plt.show()

# %%
three_sets_df = pd.concat([g1020_df, origa_df, refuge_df])
three_sets_df = three_sets_df.copy().reset_index(drop=True, inplace=False)
three_sets_df
# Out:
#                 names  types
# 0             G1020-1      0
# 1             G1020-2      0
# 2             G1020-3      0
# 3             G1020-4      0
# 4             G1020-5      0
# ...               ...    ...
# 2465  REFUGE1-val-396      0
# 2466  REFUGE1-val-397      0
# 2467  REFUGE1-val-398      0
# 2468  REFUGE1-val-399      0
# 2469  REFUGE1-val-400      0
#
# [2470 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Group by 'label' and count the occurrences, then plot as a horizontal bar chart
three_sets_df.groupby('types').size().plot(kind='barh', color=sns.color_palette('Dark2'))

# Customize the plot to match the style
plt.xlabel('Count')
plt.ylabel('Label')
plt.title('Label Distribution')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Extract prefixes from the 'names' column (assuming prefixes are separated by a hyphen)
three_sets_df['source'] = three_sets_df['names'].str.split('-').str[0]

# Count the occurrences of each source
source_counts = three_sets_df['source'].value_counts()

# Plot the distribution as a pie chart
plt.figure(figsize=(8, 8))
source_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Customize the plot
plt.title('Image Distribution by Source')
plt.ylabel('')  # Remove the y-label for a cleaner look
plt.show()

# %%
three_sets_df['types'].value_counts()
# Out:
# 0    1926
# 1     544
# Name: types, dtype: int64

# %%
# Assuming 'names' and 'types' columns are the common columns to match on
# Merge df and three_sets_df and keep only entries that are unique to df
df_remaining = df.merge(three_sets_df[['names', 'types']], on=['names', 'types'], how='left', indicator=True)

# Filter rows that are only in df (not in three_sets_df)
df_remaining = df_remaining[df_remaining['_merge'] == 'left_only']

# Drop the '_merge' column which was added by the merge function
df_remaining = df_remaining.drop(columns=['_merge'])

# Check how many are left
remaining_count = df_remaining.shape[0]
print(f"Number of entries left in df after dropping those in three_sets_df: {remaining_count}")
df_remaining['types'].value_counts()

df_remaining['types'].sum()
# Out:
# Number of entries left in df after dropping those in three_sets_df: 9846
# 4223

# %%
import matplotlib.pyplot as plt

# Group by 'label' and count the occurrences, then plot as a horizontal bar chart
df_remaining.groupby('types').size().plot(kind='barh', color=sns.color_palette('Dark2'))

# Customize the plot to match the style
plt.xlabel('Count')
plt.ylabel('Label')
plt.title('Label Distribution')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Extract prefixes from the 'names' column (assuming prefixes are separated by a hyphen)
df_remaining['source'] = df_remaining['names'].str.split('-').str[0]

# Count the occurrences of each source
source_counts = df_remaining['source'].value_counts()

# Plot the distribution as a pie chart
plt.figure(figsize=(8, 8))
source_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Customize the plot
plt.title('Image Distribution by Source')
plt.ylabel('')  # Remove the y-label for a cleaner look
plt.show()

# %%
# # for full-fundus - 3sets

# # Define the image folder
# image_folder = '/Users/nemekhbayarnomin/Documents/Graduation_project/Report1/Datasets/SMDG_dataset/full-fundus'
# dest= '/Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/full_labeled-3sets'


# # Get the list of image filenames in the folder
# image_files = os.listdir(image_folder)

# # Remove the file extension to get the image names without extensions
# image_names_no_ext = [os.path.splitext(image_file)[0] for image_file in image_files]

# # Split the DataFrame into glaucoma and non-glaucoma
# glaucoma_df = df_remaining[df_remaining['types'] == 1]  # Glaucoma images (where 'types' == 1)
# non_glaucoma_df = df_remaining[df_remaining['types'] == 0]  # Non-glaucoma images (where 'types' == 0)

# def move_images(dataframe, images_folder, destination_folder):
#     for index, row in dataframe.iterrows():
#         image_name = row['names'] + '.png'
#         label = 'glaucoma' if row['types'] == 1 else 'healthy'
        
#         destination_label_folder = os.path.join(destination_folder, label)
#         os.makedirs(destination_label_folder, exist_ok=True)
        
#         source_path = os.path.join(images_folder, image_name)
#         destination_path = os.path.join(destination_label_folder, image_name)
#         shutil.copy(source_path, destination_path)

# # Move the training images
# move_images(non_glaucoma_df, image_folder, dest)

# %%
# # for 3sets fundus images

# glaucoma_3sets_df = three_sets_df[three_sets_df['types'] == 1]
# non_glaucoma_3sets_df = three_sets_df[three_sets_df['types'] == 0]

# # Define the image folder
# image_folder = '/Users/nemekhbayarnomin/Documents/Graduation_project/Report1/Datasets/SMDG_dataset/full-fundus'
# dest= '/Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/three_sets_full_fundus'


# # Get the list of image filenames in the folder
# image_files = os.listdir(image_folder)

# # Remove the file extension to get the image names without extensions
# image_names_no_ext = [os.path.splitext(image_file)[0] for image_file in image_files]

# def move_images(dataframe, images_folder, destination_folder):
#     for index, row in dataframe.iterrows():
#         image_name = row['names'] + '.png'
#         label = 'glaucoma' if row['types'] == 1 else 'healthy'
        
#         destination_label_folder = os.path.join(destination_folder, label)
#         os.makedirs(destination_label_folder, exist_ok=True)
        
#         source_path = os.path.join(images_folder, image_name)
#         destination_path = os.path.join(destination_label_folder, image_name)
#         shutil.copy(source_path, destination_path)

# # Move the training images
# move_images(non_glaucoma_3sets_df, image_folder, dest)

# %%
# for full-fundus - 3sets ROI

glaucoma_remaining_df = df_remaining[df_remaining['types'] == 1]
non_glaucoma_remaining_df = df_remaining[df_remaining['types'] == 0]

# Define the image folder
image_folder = '/Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged'
dest= '/Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/remaining_roi_full_rgb_labeled'


# Get the list of image filenames in the folder
image_files = os.listdir(image_folder)

# Remove the file extension to get the image names without extensions
image_names_no_ext = [os.path.splitext(image_file)[0] for image_file in image_files]


def move_images(dataframe, images_folder, destination_folder):
    for index, row in dataframe.iterrows():
        image_name = row['names'] + '.tiff'
        label = 'glaucoma' if row['types'] == 1 else 'healthy'
        
        destination_label_folder = os.path.join(destination_folder, label)
        os.makedirs(destination_label_folder, exist_ok=True)
        
        source_path = os.path.join(images_folder, image_name)
        destination_path = os.path.join(destination_label_folder, image_name)
        
        if os.path.exists(source_path):
            shutil.copy(source_path, destination_path)
        else:
            print(f"File not found, skipping: {source_path}")

# Move the training images
move_images(non_glaucoma_remaining_df, image_folder, dest)
# Out:
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-15.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-28.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-51.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-92.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-137.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-141.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-144.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-163.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-168.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-171.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-174.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-181.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-196.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-297.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-306.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-320.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-322.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-324.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-331.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-373.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-378.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-421.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-446.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-448.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-455.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-456.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-486.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-492.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-529.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-638.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-641.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-674.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-690.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-711.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-730.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-747.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-751.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-756.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-760.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-780.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-784.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-786.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-787.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-796.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-799.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-800.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-801.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-803.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-815.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-816.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-834.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-855.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-862.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-872.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-873.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-880.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-885.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-887.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-908.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-911.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-931.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-932.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-935.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-939.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-958.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-983.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-984.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-991.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1293.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1317.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1318.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1321.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1323.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1324.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1332.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1347.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1362.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1365.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1421.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1431.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1432.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1455.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1456.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1481.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1494.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1499.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1513.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1547.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1548.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1579.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1580.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1626.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1627.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1638.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1647.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1648.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1660.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1685.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1686.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1700.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1706.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1708.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1727.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1746.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1757.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1762.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1782.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1793.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1803.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1817.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1818.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1834.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1855.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1893.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1901.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1902.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1935.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1937.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1973.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1974.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1980.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1995.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-1996.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2021.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2022.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2025.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2026.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2050.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2051.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2052.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2070.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2077.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2078.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2079.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2083.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2096.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2106.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2108.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2133.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2139.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2146.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2168.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2201.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2202.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2207.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2209.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2210.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2224.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2236.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2251.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2252.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2257.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2258.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2274.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2294.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2303.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2343.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2344.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2376.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2400.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2422.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2436.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2441.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2446.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2457.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2458.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2461.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2462.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2479.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2486.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2490.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2507.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2508.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2512.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2519.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2520.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2544.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2545.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2546.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2559.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2573.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2574.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2585.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2598.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2619.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2627.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2651.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2675.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2694.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2788.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2815.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2832.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2833.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2837.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2838.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2846.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2860.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2868.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2872.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2921.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2922.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2925.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2926.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2935.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2954.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2976.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2989.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-2991.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3002.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3014.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3024.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3041.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3042.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3045.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3046.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3079.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3119.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3133.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3136.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3159.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3168.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3187.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3202.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3218.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3223.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3246.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/OIA-ODIR-TRAIN-3256.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/sjchoi86-HRF-160.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/sjchoi86-HRF-199.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/sjchoi86-HRF-224.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/sjchoi86-HRF-252.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/sjchoi86-HRF-297.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-33.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-85.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-88.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-90.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-103.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-104.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-126.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-127.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-129.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-159.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-162.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-201.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-221.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-334.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-341.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-347.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-361.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-373.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-406.tiff
# File not found, skipping: /Users/nemekhbayarnomin/Documents/Graduation_project/dataset/3_dataset/roi_roi_full_rgb_merged/PAPILA-428.tiff
